# %%
list=[10,20,30,"Nitin","python",40]
print(list)
# Out:
# [10, 20, 30, 'Nitin', 'python', 40]

# %%
list.append(50)
print(list)
# Out:
# [10, 20, 30, 'Nitin', 'python', 40, 50]

# %%
list.insert(2,70)
print(list)
# Out:
# [10, 20, 70, 30, 'Nitin', 'python', 40, 50, 70]
